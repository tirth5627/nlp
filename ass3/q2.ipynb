# %%
import matplotlib.pyplot as plt
import pandas as pd

def create_freq_dist(tokens):
    freq_dist = {}
    for token in tokens:
        token = token.lower()  
        if token in freq_dist:
            freq_dist[token] += 1
        else:
            freq_dist[token] = 1
    return freq_dist

try:
    df_word = pd.read_parquet("../ass1/gujarati_word_tokenized.parquet", engine="pyarrow")
    all_tokens = df_word["sentence"].dropna().astype(str).tolist()

except FileNotFoundError:
    print("Error: 'gujarati_word_tokenized.parquet' not found.")
    all_tokens = []
except ValueError as e:
    print(f"Error reading Parquet file: {e}")
    all_tokens = []

if all_tokens:
    initial_freq_dist = create_freq_dist(all_tokens)
    print(f"Successfully created frequency distribution for {len(initial_freq_dist)} unique tokens.")
else:
    initial_freq_dist = {}


def plot_freq_dist(freq_dist, top_n, title):
    sorted_items = sorted(freq_dist.items(), key=lambda item: item[1], reverse=True)

    top_words = [item[0] for item in sorted_items[:top_n]]
    top_freqs = [item[1] for item in sorted_items[:top_n]]

    plt.figure(figsize=(20, 8))
    plt.bar(top_words, top_freqs, color='darkcyan')
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

if initial_freq_dist:
    plot_freq_dist(
        initial_freq_dist,
        top_n=100,
        title='📊 Top 100 Most Frequent Words (Before Stop Word Removal)'
    )

def remove_stopwords_by_freq(freq_dist, threshold):
    stop_words = {word for word, freq in freq_dist.items() if freq > threshold}

    print(f"\nThreshold: >{threshold}. Found {len(stop_words)} stop words.")
    stop_words_sample = sorted(list(stop_words))[:20]
    print(f"Stop words found (sample): {stop_words_sample}")
    filtered_dist = {
        word: freq for word, freq in freq_dist.items() if word not in stop_words
    }
    return filtered_dist

if initial_freq_dist:
    thresholds = [50000, 25000, 10000]

    for i, threshold_val in enumerate(thresholds, 1):
        filtered_dist = remove_stopwords_by_freq(initial_freq_dist, threshold_val)
        plot_freq_dist(
            filtered_dist,
            top_n=100,
            title=f'🗑️ Top 100 Words (Stop Words with Freq > {threshold_val} Removed)'
        )
# Out:
# Successfully created frequency distribution for 2645410 unique tokens.
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2715 (\N{GUJARATI LETTER CHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Gujarati natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2759 (\N{GUJARATI VOWEL SIGN E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2693 (\N{GUJARATI LETTER A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2728 (\N{GUJARATI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2694 (\N{GUJARATI LETTER AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2709 (\N{GUJARATI LETTER KA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2730 (\N{GUJARATI LETTER PA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2723 (\N{GUJARATI LETTER NNA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2734 (\N{GUJARATI LETTER MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2750 (\N{GUJARATI VOWEL SIGN AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2719 (\N{GUJARATI LETTER TTA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2703 (\N{GUJARATI LETTER E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2736 (\N{GUJARATI LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2752 (\N{GUJARATI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2724 (\N{GUJARATI LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2716 (\N{GUJARATI LETTER JA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2744 (\N{GUJARATI LETTER SA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2725 (\N{GUJARATI LETTER THA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2745 (\N{GUJARATI LETTER HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2763 (\N{GUJARATI VOWEL SIGN O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2741 (\N{GUJARATI LETTER VA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2690 (\N{GUJARATI SIGN ANUSVARA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2753 (\N{GUJARATI VOWEL SIGN U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2735 (\N{GUJARATI LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2726 (\N{GUJARATI LETTER DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2765 (\N{GUJARATI SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2742 (\N{GUJARATI LETTER SHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2696 (\N{GUJARATI LETTER II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2727 (\N{GUJARATI LETTER DHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2732 (\N{GUJARATI LETTER BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2738 (\N{GUJARATI LETTER LA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2739 (\N{GUJARATI LETTER LLA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2707 (\N{GUJARATI LETTER O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2695 (\N{GUJARATI LETTER I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2751 (\N{GUJARATI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2764 (\N{GUJARATI VOWEL SIGN AU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2754 (\N{GUJARATI VOWEL SIGN UU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2711 (\N{GUJARATI LETTER GA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Threshold: >50000. Found 516 stop words.
# Stop words found (sample): ['!', '"', "'", '(', ')', ',', '-', '.', '/', '1', '10', '12', '15', '2', '20', '3', '4', '5', '6', '7']
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128465 (\N{WASTEBASKET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2714 (\N{GUJARATI LETTER CA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2710 (\N{GUJARATI LETTER KHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2743 (\N{GUJARATI LETTER SSA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2760 (\N{GUJARATI VOWEL SIGN AI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2793 (\N{GUJARATI DIGIT THREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2697 (\N{GUJARATI LETTER U}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2792 (\N{GUJARATI DIGIT TWO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2721 (\N{GUJARATI LETTER DDA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2733 (\N{GUJARATI LETTER BHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2720 (\N{GUJARATI LETTER TTHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2717 (\N{GUJARATI LETTER JHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2794 (\N{GUJARATI DIGIT FOUR}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Threshold: >25000. Found 1037 stop words.
# Stop words found (sample): ['!', '"', '%', "'", '(', ')', ',', '-', '.', '/', '1', '10', '100', '11', '12', '13', '14', '15', '16', '18']
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2722 (\N{GUJARATI LETTER DDHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2712 (\N{GUJARATI LETTER GHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2731 (\N{GUJARATI LETTER PHA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Threshold: >10000. Found 2578 stop words.
# Stop words found (sample): ['!', '"', '$', '%', "'", '(', ')', '*', '+', ',', '-', '.', '/', '1', '10', '100', '11', '12', '13', '14']
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2691 (\N{GUJARATI SIGN VISARGA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2718 (\N{GUJARATI LETTER NYA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2798 (\N{GUJARATI DIGIT EIGHT}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Acer\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2755 (\N{GUJARATI VOWEL SIGN VOCALIC R}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
